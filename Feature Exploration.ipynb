# %% [markdown]
# ## Set-up

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
plt.rcParams['figure.figsize'] = [30, 30]

# %%
category = [
    'age',
    'workclass',
    'fnlwgt',
    'education',
    'education-num',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'capital-gain',
    'capital-loss',
    'hours-per-week',
    'native-country',
    'income'
]

# %%
train_data = pd.read_csv('adult_data.csv', names=category);
train_data;

# %% [markdown]
# ## Study the data

# %%
sns.countplot(y='age', hue='income', data=train_data);

# %%
wc = sns.countplot(y='workclass', hue='income', data=train_data)
#wc.set_xscale('log')

# %%
sns.countplot(y='education', hue='income', data=train_data)
# Out:
# <AxesSubplot:xlabel='count', ylabel='education'>

# %%
sns.countplot(y='education-num', hue='income', data=train_data)
# Out:
# <AxesSubplot:xlabel='count', ylabel='education-num'>

# %%
sns.countplot(y='marital-status', hue='income', data=train_data)
# Out:
# <AxesSubplot:xlabel='count', ylabel='marital-status'>

# %%
sns.countplot(y='occupation', hue='income', data=train_data)
# Out:
# <AxesSubplot:xlabel='count', ylabel='occupation'>

# %%
sns.countplot(y='relationship', hue='income', data=train_data)
# Out:
# <AxesSubplot:xlabel='count', ylabel='relationship'>

# %%
sns.countplot(y='race', hue='income', data=train_data)
# Out:
# <AxesSubplot:xlabel='count', ylabel='race'>

# %%
sns.countplot(y='sex', hue='income', data=train_data)
# Out:
# <AxesSubplot:xlabel='count', ylabel='sex'>

# %%
cg = sns.countplot(y='capital-gain', hue='income', data=train_data);
cg.set_xscale('log')

# %%
cp = sns.countplot(y='capital-loss', hue='income', data=train_data)
cp.set_xscale('log')

# %%
hpw = sns.countplot(y='hours-per-week', hue='income', data=train_data)
hpw.set_xscale('log')

# %%
nc = sns.countplot(y='native-country', hue='income', data=train_data)
#nc.set_xscale('log')

# %%
for item in category:
    count_data = train_data[item].value_counts()
    count_data.to_csv('count_data/'+item+'.csv')

# %%
train_data['age'].value_counts()
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 85      3
# 88      3
# 87      1
# 86      1
# Name: age, Length: 73, dtype: int64

# %%
train_data.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
## Study the data

sns.countplot(y='age', hue='income', data=train_data);

wc = sns.countplot(y='workclass', hue='income', data=train_data)
#wc.set_xscale('log')

sns.countplot(y='fnlwgt', hue='income', data=train_data);#NO NEED TO COUNT
#People with similar demographic characteristics should have similar weights.

sns.countplot(y='education', hue='income', data=train_data)

sns.countplot(y='education-num', hue='income', data=train_data)

sns.countplot(y='marital-status', hue='income', data=train_data)


sns.countplot(y='occupation', hue='income', data=train_data)

sns.countplot(y='relationship', hue='income', data=train_data)

sns.countplot(y='race', hue='income', data=train_data)

sns.countplot(y='sex', hue='income', data=train_data)

cg = sns.countplot(y='capital-gain', hue='income', data=train_data);
cg.set_xscale('log')

cp = sns.countplot(y='capital-loss', hue='income', data=train_data)
cp.set_xscale('log')

hpw = sns.countplot(y='hours-per-week', hue='income', data=train_data)
hpw.set_xscale('log')

nc = sns.countplot(y='native-country', hue='income', data=train_data)
#nc.set_xscale('log')

for item in category:
    count_data = train_data[item].value_counts()
    count_data.to_csv('count_data/'+item+'.csv')

train_data['age'].value_counts()

























train_data.describe()test_data = pd.read_csv('adult_test.csv', names=category);
test_data;
